# %%
import pandas as pd

from utils import *

# %%
created_data = get_data(filename='tiny_dataset.parquet', frac=0.0005)
# Out:
# File /Users/thomasfuller/ML/spectrum/data/tiny_dataset.parquet not found
# Generating data from base data set...
# Reading data from /Users/thomasfuller/ML/spectrum/data/DB_for_chromophore_Sci_Data_rev02.csv...
#
# Taking a random sample of 10 rows...
#
# Calculating 1613 Mordred descriptors for each row...
#  60%|██████    | 6/10 [00:01<00:02,  1.46it/s]
# /Users/thomasfuller/ML/spectrum/envs/lib/python3.8/site-packages/numpy/core/fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/thomasfuller/ML/spectrum/envs/lib/python3.8/site-packages/numpy/core/fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████| 10/10 [00:03<00:00,  3.02it/s]
# /Users/thomasfuller/ML/spectrum/envs/lib/python3.8/site-packages/numpy/core/fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
# ...

# %%
created_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Columns: 1625 entries, SMILES to mZagreb2
# dtypes: bool(1), float64(1623), object(1)
# memory usage: 127.0+ KB

# %%
created_data
# Out:
#                                               SMILES  LambdaMaxAbs  \
# 0                   Oc1ccccc1/C=N/c1ccc(Cn2cncn2)cc1    290.006380
# 1  c1ccc(-c2c3ccc(=[N+]4CCCCC4)cc-3oc3cc(N4CCCCC4...    565.000000
# 2  CC(=O)OC[C@H]1O[C@@H]([C@@H]2C=C(Cl)C(=S)NC2=O...    440.000000
# 3  Fc1ccc(-c2cc3ccc4cc(-c5ccc(F)cc5)cc5ccc(c2)c3c...           NaN
# 4  [O-]c1c(-c2ccccc2)cc(-[n+]2c(-c3ccccc3)cc(-c3c...    536.416510
# 5      C(=C/c1ccc(-c2ccncc2)cc1)\c1ccc(-c2ccncc2)cc1    345.000000
# 6  CN(C)c1ccc(/C=C/c2cc[n+](CCCCCCCCCCCC[n+]3ccc(...    476.000076
# 7                       N#Cc1ccc(C[C@H](N)C(=O)O)cc1           NaN
# 8  CCN(CC)c1ccc([N+]2=Cc3ccc4c5c(ccc4c3O[B-]2(c2c...    552.000000
# 9                       CCC(=O)c1ccc2cc(N(C)C)ccc2c1    359.000000
#
#    LambdaMaxEm  Lifetime     QY  LogExtCoeff  AbsFWHMcm-1  EmFWHMcm-1  \
# 0   363.993739       NaN    NaN          NaN          NaN         NaN
# 1   585.000000       NaN  0.890     5.025306          NaN         NaN
# ...

# %%
bool_column = created_data.columns[created_data.dtypes == 'bool']
bool_column
# Out:
# Index(['Mol'], dtype='object')
